# %%
! pip install tts_uk

# %%
import torchaudio

from IPython.display import Audio, display

# %%
from tts_uk.inference import synthesis
# Out:
# Inference device: cuda
# model_dap_84000_state.pt:   0%|          | 0.00/930M [00:00<?, ?B/s]
# config.yaml:   0%|          | 0.00/526 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/56.3M [00:00<?, ?B/s]
# Applying spectral norm to text encoder LSTM
# Applying spectral norm to context encoder LSTM
# Loaded checkpoint (RAD-TTS++), number of parameters: 229,103,605
# Loaded checkpoint (Vocos), number of parameters: 13,985,282

# %%
mels, wave, stats = synthesis(
    text="Ви можете протестувати синтез мовлення українською мовою. Просто введіть текст, який ви хочете прослухати.",
    voice="tetiana",  # voice: tetiana, mykyta, lada
    n_takes=1,
    use_latest_take=False,
    token_dur_scaling=1,
    f0_mean=0,
    f0_std=0,
    energy_mean=0,
    energy_std=0,
    sigma_decoder=0.8,
    sigma_token_duration=0.666,
    sigma_f0=1,
    sigma_energy=1,
)

print(stats)
# Out:
# Inferencing take 1
# {'rtf': 0.19244510162552106, 'time': 1.4344098567962646, 'audio_duration': 7.453605442176871, 'speed_ratio': 5.19628710501502, 'speech_rate': 1.8782856308411215}

# %%
torchaudio.save("audio.wav", wave.cpu(), 44_100, encoding="PCM_S")

display(Audio("audio.wav"))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
